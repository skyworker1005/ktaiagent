# %% [markdown]
# # Debate - 토론하는 에이전트

# %%
from dotenv import load_dotenv
import os
from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import AzureChatOpenAI
from langchain_core.output_parsers import StrOutputParser

load_dotenv('../env', override=True)
AZURE_OPENAI_API_KEY = os.getenv('AZURE_OPENAI_API_KEY')
END_POINT=os.getenv('END_POINT')
MODEL_NAME=os.getenv('MODEL_NAME')
MODEL_API_VERSION=os.getenv('MODEL_API_VERSION')
if MODEL_API_VERSION:
    os.environ['MODEL_API_VERSION'] = MODEL_API_VERSION
if AZURE_OPENAI_API_KEY:
    print(AZURE_OPENAI_API_KEY[:10])
else:
    print("AZURE_OPENAI_API_KEY가 설정되지 않았습니다.")
print(MODEL_NAME, MODEL_API_VERSION)

langsmith_key = os.getenv('LANGSMITH_API_KEY')
if langsmith_key:
    os.environ['LANGCHAIN_API_KEY'] = langsmith_key
ep = os.getenv('LANGCHAIN_ENDPOINT')
if ep:
    os.environ['LANGCHAIN_ENDPOINT'] = ep
os.environ['LANGCHAIN_TRACING_V2'] = 'false'
os.environ['LANGCHAIN_PROJECT'] = 'AGENT'

if os.getenv('LANGCHAIN_TRACING_V2') == "true":
    _lk = os.getenv('LANGSMITH_API_KEY')
    if _lk and len(_lk) > 0:
        print('랭스미스로 추적 중입니다 :', _lk[:10])
    else:
        print('랭스미스 키가 확인되지 않았습니다.')
# Out:
# Em4f4T5UbT
# gpt-5-nano 2025-01-01-preview

# %%
from langchain_tavily import TavilySearch
from langchain.agents import create_agent
from langchain.agents.middleware import dynamic_prompt, ModelRequest
from dataclasses import dataclass

tavily_api_key = os.getenv("TAVILY_API_KEY")
web_search_tool = TavilySearch(max_results=5, api_key=tavily_api_key)

# %%
from typing import TypedDict, Dict, Any, Literal, List
from langgraph.graph import StateGraph, START, END
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.messages import HumanMessage, AIMessage
from langchain_core.output_parsers import StrOutputParser

llm = AzureChatOpenAI(
    api_key=AZURE_OPENAI_API_KEY,
    azure_endpoint=END_POINT,
    azure_deployment=MODEL_NAME,
    api_version=os.environ.get('MODEL_API_VERSION', '2024-12-01-preview'),
    model = MODEL_NAME,
)

class S(TypedDict, total=False):
    topic: str
    max_turns: int
    turn: int
    last_speaker: Literal["prog","cons","none"]
    prog_history: List[str]
    cons_history: List[str]
    transcript: List[str]
    final_report: str
    moderator_questions: str

P_SUM = ChatPromptTemplate.from_template(
    """다음 토론 기록에서 마지막 몇 턴의 발언을 바탕으로,
(1) 상대가 제기한 '핵심 타당한 주장' 몇 개, (2) '논쟁 중인 쟁점' 몇 개,
(3) '이미 합의된 지점' 몇 개를 불릿으로 5줄 이내 요약하세요.
중복/수사는 빼고 핵심만 적으세요.

--- 발언 요약용 입력 ---
{snippet}
"""
)

def summarize_context(lines: List[str]) -> str:
    """직전 발언들을 토대로 요약(수용/쟁점/합의) 5줄 이내"""
    snippet = "\n\n".join(lines[-2:]) if lines else "(발언 없음)"
    msg = P_SUM.format(snippet=snippet)
    return llm.invoke(msg).content.strip()


# 사회자 프롬프트: 주제로부터 논쟁의 화두 제안
P_MODERATOR = ChatPromptTemplate.from_template(
    """당신은 토론의 사회자입니다.
주어진 토론 주제를 바탕으로, 진보와 보수가 논쟁할 수 있는 핵심 쟁점 3~5개를 간단하게 제시하세요.
각 쟁점은 1~2문장으로 간결하게 작성하세요.

주제: {topic}

다음 형식으로 작성하세요:
1. [쟁점 1]
2. [쟁점 2]
3. [쟁점 3]
...
"""
)

def moderator(state: S) -> Dict[str, Any]:
    """사회자 노드: 주제로부터 논쟁의 화두 제안"""
    chain = P_MODERATOR | llm | StrOutputParser()
    questions = chain.invoke({"topic": state["topic"]})
    transcript = (state.get("transcript") or []) + [f"[사회자] {questions}"]
    return {
        "moderator_questions": questions,
        "transcript": transcript,
    }

# 라우터: 랜덤으로 보수 또는 진보 선택
import random

def router(state: S) -> Literal["progressive", "conservative"]:
    """라우터: 랜덤으로 첫 발언자 선택"""
    choice = random.choice(["progressive", "conservative"])
    return choice


@dataclass
class DebateContext:
    turn: int

# 진보 에이전트용 dynamic_prompt
@dynamic_prompt
def progressive_dynamic_prompt(request: ModelRequest) -> str:
    base = """당신은 '진보' 관점의 정책 토론 에이전트입니다. 평등, 자유, 인권, 사회적 정의를 추구하며, 적극적 복지정책, 사회적 불평등 완화, 소외계층 지원, 환경 보호, 문화 다양성 존중, 교육 확대 등을 선호합니다.

[규칙]
- 필요시 tavily_search 도구로 논거를 뒷받침할 객관적 사실·통계·사례를 검색한 뒤 인용하세요.
- 이전 주장과 동일한 문장을 반복하지 마세요. 동일 논지는 새로운 근거·사실로 보강하세요.
- 구체적 정책 수단(과세/지원/규제/인센티브/감독/지표/일몰조항 등)을 포함하세요.
- 추상적 의견은 피하고 실질적으로 적용 가능한 구체적 정책을 주장하세요.
- 예산/처벌/평가가 필요할 경우 구체적 수준과 기준을 포함하세요.
- 길이: 6~10문장, 한국어."""

    context = request.runtime.context if hasattr(request.runtime, 'context') else None
    turn = context.turn if context else 0

    if turn == 0:
        base += "\n\n[중요] 첫 발언입니다. 상대 발언에 대한 수용/반박 없이 바로 본인의 주장을 시작하세요."
        base += "\n\n[응답 포맷]\n1) 주장 2) 근거 3) 정책 제안 4) 실행 지표 5) 결론"
    else:
        base += "\n\n- 상대의 타당한 지점 1개 이상을 명시적으로 수용하고 그 위에서 개선·타협안을 제시하세요."
        base += "\n\n[응답 포맷]\n1) 수용 2) 비판/보완 3) 개선·타협안 4) 실행 지표 5) 결론"

    return base

prog_agent = create_agent(llm, tools=[web_search_tool], middleware=[progressive_dynamic_prompt], context_schema=DebateContext)

P_PROG = ChatPromptTemplate.from_template(
    """[컨텍스트 요약]
{context}

[당신 직전 발언]
{own_last}

주제: {topic}

[사회자 제시 화두]
{moderator_questions}

[상대 직전 주장]
{opponent_last}"""
)

def progressive_agent(state: S) -> Dict[str, Any]:
    turn = state.get("turn", 0)
    transcript = state.get("transcript", [])
    prog_hist = state.get("prog_history") or []
    cons_hist = state.get("cons_history") or []
    context = "(첫 발언)" if turn == 0 else summarize_context(transcript)
    prompt_text = P_PROG.format(
        context=context,
        own_last=(prog_hist or ["(없음)"])[-1],
        topic=state["topic"],
        moderator_questions=state.get("moderator_questions", ""),
        opponent_last=(cons_hist or ["(없음)"])[-1],
    )

    result = prog_agent.invoke(
        {"messages": [HumanMessage(content=prompt_text)]},
        config={"configurable": {"context": DebateContext(turn=turn)}}
    )

    out = result["messages"][-1].content.strip()
    prog_hist = (state.get("prog_history") or []) + [out]
    if len(prog_hist) > 2:
        prog_hist = prog_hist[-2:]

    return {
        "prog_history": prog_hist,
        "transcript": transcript + [f"[진보] {out}"],
        "turn": turn + 1,
        "last_speaker": "prog",
    }

# %%
# 보수 에이전트용 dynamic_prompt
@dynamic_prompt
def conservative_dynamic_prompt(request: ModelRequest) -> str:
    base = """당신은 '보수' 관점의 정책 토론 에이전트입니다. 전통, 질서, 안정, 점진적 변화를 추구하며, 최소한의 정부 개입, 개인의 책임 강조, 자유시장 중심의 경제 체제를 선호합니다.

[규칙]
- 필요시 tavily_search 도구로 논거를 뒷받침할 객관적 사실·통계·사례를 검색한 뒤 인용하세요.
- 이전 주장과 동일한 문장을 반복하지 마세요. 동일 논지는 새로운 근거·사실로 보강하세요.
- 구체적 정책 수단(규제 최소화/자율규제/세제/성과기반/단계적 시행 등)을 포함하세요.
- 추상적 의견은 피하고 실질적으로 적용 가능한 구체적 정책을 주장하세요.
- 예산/처벌/평가가 필요할 경우 구체적 수준과 기준을 포함하세요.
- 길이: 6~10문장, 한국어."""

    context = request.runtime.context if hasattr(request.runtime, 'context') else None
    turn = context.turn if context else 0

    if turn == 0:
        base += "\n\n[중요] 첫 발언입니다. 상대 발언에 대한 수용/반박 없이 바로 본인의 주장을 시작하세요."
        base += "\n\n[응답 포맷]\n1) 주장 2) 근거 3) 정책 제안 4) 실행 지표 5) 결론"
    else:
        base += "\n\n- 상대의 타당한 주장 1개 이상을 명시적으로 수용하고, 비용/부작용/막을 장치 관점에서 보완안을 제시하세요."
        base += "\n\n[응답 포맷]\n1) 수용 2) 비판/보완 3) 개선·타협안 4) 실행 지표 5) 결론"

    return base

cons_agent = create_agent(llm, tools=[web_search_tool], middleware=[conservative_dynamic_prompt], context_schema=DebateContext)

P_CONS = ChatPromptTemplate.from_template(
    """[컨텍스트 요약]
{context}

[당신 직전 발언]
{own_last}

주제: {topic}

[사회자 제시 화두]
{moderator_questions}

[상대 직전 주장]
{opponent_last}"""
)

def conservative_agent(state: S) -> Dict[str, Any]:
    turn = state.get("turn", 0)
    transcript = state.get("transcript", [])
    prog_hist = state.get("prog_history") or []
    cons_hist = state.get("cons_history") or []
    context = "(첫 발언)" if turn == 0 else summarize_context(transcript)
    prompt_text = P_CONS.format(
        context=context,
        own_last=(cons_hist or ["(없음)"])[-1],
        topic=state["topic"],
        moderator_questions=state.get("moderator_questions", ""),
        opponent_last=(prog_hist or ["(없음)"])[-1],
    )

    result = cons_agent.invoke(
        {"messages": [HumanMessage(content=prompt_text)]},
        config={"configurable": {"context": DebateContext(turn=turn)}}
    )

    out = result["messages"][-1].content.strip()
    cons_hist = (state.get("cons_history") or []) + [out]
    if len(cons_hist) > 2:
        cons_hist = cons_hist[-2:]

    return {
        "cons_history": cons_hist,
        "transcript": transcript + [f"[보수] {out}"],
        "turn": turn + 1,
        "last_speaker": "cons",
    }

# %%
P_JUDGE = ChatPromptTemplate.from_template(
    """당신은 토론의 심판·조정자입니다.
아래 '진보(prog)/보수(cons)' 토론 기록을 바탕으로 (발언에 웹 검색으로 확인한 사실이 인용되었을 수 있음):
1) 핵심 쟁점 3~5개
2) 합의된 지점 2~4개
3) 타협 가능한 정책 패키지(단계·지표·예산원칙 포함)
4) 권고안 초안(조문 형태 요지, 6~10문장)
을 한국어로 간결히 정리하세요.
추상적인 내용이 아니라 도입할 수 있는 제도로서의 의미가 있는 구체적인 결과로 정리하세요.
과도한 감정·편향을 피하고 검증 가능한 표현을 사용하세요.

--- 토론 전체 기록 ---
{transcript}
"""
)

def judge(state: S) -> Dict[str, Any]:
    transcript_text = "\n\n".join(state["transcript"])

    chain = P_JUDGE | llm | StrOutputParser()
    out = chain.invoke({"transcript": transcript_text})
    return {"final_report": out}

# %%
MAX_TURNS = 2

def choose_after_prog(state: S) -> Literal["to_cons", "to_end"]:
    turn = int(state.get("turn", 0))
    max_turns = int(state.get("max_turns", MAX_TURNS))
    return "to_end" if turn >= max_turns else "to_cons"

def choose_after_cons(state: S) -> Literal["to_prog", "to_end"]:
    turn = int(state.get("turn", 0))
    max_turns = int(state.get("max_turns", MAX_TURNS))
    return "to_end" if turn >= max_turns else "to_prog"

g = StateGraph(S,
                input_keys=["topic", "max_turns"],
                output_keys=["final_report"],
                )

g.add_node("moderator", moderator)
g.add_node("progressive", progressive_agent)
g.add_node("conservative", conservative_agent)
g.add_node("judge", judge)

# 워크플로우: START -> moderator -> (progressive/conservative) -> ...
g.add_edge(START, "moderator")
g.add_conditional_edges("moderator", router, {
    "progressive": "progressive",
    "conservative": "conservative",
})

g.add_conditional_edges("progressive", choose_after_prog, {
    "to_cons": "conservative",
    "to_end": "judge",
})

g.add_conditional_edges("conservative", choose_after_cons, {
    "to_prog": "progressive",
    "to_end": "judge",
})
g.add_edge("judge", END)

graph = g.compile()

# %%
graph

# %%
topic = "온라인 아동·청소년 게임 중독을 막기 위한 셧다운 제도의 도입 혹은 폐지. 진보는 셧다운 제도를 도입하고 보수는 폐지하는 것을 주장합니다."
out = graph.stream({"topic": topic, "max_turns": 4})
for stage in out:
    print(stage)

print("\n\n")
print(stage['judge']['final_report'])
# Out:
# {'moderator': {'moderator_questions': '1. 효과성 및 부작용\n- 셧다운 제도가 아동·청소년의 게임 시간과 문제행동 감소에 실제로 효과가 있을까? 한편으로는 우회 수단 증가나 부작용이 나타날 가능성도 있다.\n\n2. 자유와 가족 책임의 균형\n- 청소년의 자유와 학습권을 보호하는 동시에 가족의 감독 권한과 사회적 책임의 균형은 어떻게 설정할 것인가? 제도 도입으로 가족 부담과 개입이 과도해지지 않는가?\n\n3. 산업 영향과 혁신\n- 제도 도입이 게임 산업의 혁신과 성장에 어떤 제약을 주며, 글로벌 플랫폼 간 규제 차이를 어떻게 조정할 것인가? 집행의 국제적 조화와 경쟁력 저하 우려는 없는가?\n\n4. 형평성과 사회적 비용\n- 디지털 격차가 큰 저소득층이나 지역 간 불리함을 심화시키지 않는가? 정책 설계에서 형평성과 취약계층 보호를 어떻게 보장할 것인가?\n\n5. 실행성과 개인정보보호\n- 나이 인증·활동 제한의 기술적 구현이 개인정보보호와 보안에 어떤 위험을 가져오며, 비용과 행정 부담은 충분히 감당 가능한가?', 'transcript': ['[사회자] 1. 효과성 및 부작용\n- 셧다운 제도가 아동·청소년의 게임 시간과 문제행동 감소에 실제로 효과가 있을까? 한편으로는 우회 수단 증가나 부작용이 나타날 가능성도 있다.\n\n2. 자유와 가족 책임의 균형\n- 청소년의 자유와 학습권을 보호하는 동시에 가족의 감독 권한과 사회적 책임의 균형은 어떻게 설정할 것인가? 제도 도입으로 가족 부담과 개입이 과도해지지 않는가?\n\n3. 산업 영향과 혁신\n- 제도 도입이 게임 산업의 혁신과 성장에 어떤 제약을 주며, 글로벌 플랫폼 간 규제 차이를 어떻게 조정할 것인가? 집행의 국제적 조화와 경쟁력 저하 우려는 없는가?\n\n4. 형평성과 사회적 비용\n- 디지털 격차가 큰 저소득층이나 지역 간 불리함을 심화시키지 않는가? 정책 설계에서 형평성과 취약계층 보호를 어떻게 보장할 것인가?\n\n5. 실행성과 개인정보보호\n- 나이 인증·활동 제한의 기술적 구현이 개인정보보호와 보안에 어떤 위험을 가져오며, 비용과 행정 부담은 충분히 감당 가능한가?']}}
# {'progressive': {'prog_history': ['1) 주장\n온라인 아동·청소년의 건강권과 학습권을 지키기 위해 셧다운 제도를 도입하는 것이 필요하다. 다만 제도 단독으로 효과를 보장하기 어렵다는 점을 인정하고, 가족 지원·교육 확충 등 보완책과 함께 설계해야 한다.\n\n2) 근거\n2014년 국내 연구는 셧다운제가 중독의 유발 원인과 강력한 1대1 상관관계를 증명하기 어렵고, 제도만으로 중독을 예방하기는 한계가 있음을 지적한다. 그러나 2017년 연세대 연구는 셧다운 제도가 인터넷 사용 습관과 수면 시간 등에 긍정적 영향을 미친다는 근거를 제시하며, 정책의 효과가 일부 존재함을 시사한다.\n\n3) 정책 제안\n- 법제화: 만 16세 이하에 대한 강제 셧다운을 기본으로 하고, 교육용 콘텐츠와 필수 커뮤니케이션 플랫폼 이용은 예외로 두되 엄격한 실시간 모니터링과 로그 남김을 의무화한다. 개인정보 최소수집 원칙을 적용하고, 연령 확인은 공공인증 시스템과 가명화된 데이터 처리로 보안 강화한다. \n- 가족·학교 지원: 가정에 대한 감독 지원금(가정 내 가족 상담·디지털 시민성 교육 비용), 학교마다 디지털 안전교실 정규과정 도입, 지역사회 상담 핫라인 운영으로 가족 부담을 분산한다.\n- 산업과 국제 협력: 국내 규제의 안정화를 위해 단계적 이행 로드맵을 마련하고, 국제 규제 차이에 따른 글로벌 플랫폼 협의체를 통해 기술표준과 개인정보 보호 기준의 국제적 조화를 추진한다.\n\n4) 실행 지표\n- 연 1회씩 독립기관에 의한 평가를 의무화하고, 3개 주요 지표로 효과를 측정한다: (a) 야간 접속 비율의 감소율(전년 대비 %), (b) 인터넷 중독 위험 척도 점수의 변화, (c) 학교 출석·학업성취도·수면시간의 개선지표. 목표치로는 3년간 야간 접속 20% 감소, 중독 위험 척도 15% 감소, 수면시간 30분 이상 증가를 설정한다.\n\n5) 결론\n셧다운 제도는 청소년의 건강과 교육환경을 보호하는 공익적 도구로서 필요하며, 보완정책과 근본적 사회지원과 함께 추진될 때 효과를 극대화할 수 있다. 이를 통해 디지털 격차를 줄이고 가정‧학교‧지역사회가 함께 책임지는 건강한 디지털 문화의 토대를 마련하자.'], 'transcript': ['[사회자] 1. 효과성 및 부작용\n- 셧다운 제도가 아동·청소년의 게임 시간과 문제행동 감소에 실제로 효과가 있을까? 한편으로는 우회 수단 증가나 부작용이 나타날 가능성도 있다.\n\n2. 자유와 가족 책임의 균형\n- 청소년의 자유와 학습권을 보호하는 동시에 가족의 감독 권한과 사회적 책임의 균형은 어떻게 설정할 것인가? 제도 도입으로 가족 부담과 개입이 과도해지지 않는가?\n\n3. 산업 영향과 혁신\n- 제도 도입이 게임 산업의 혁신과 성장에 어떤 제약을 주며, 글로벌 플랫폼 간 규제 차이를 어떻게 조정할 것인가? 집행의 국제적 조화와 경쟁력 저하 우려는 없는가?\n\n4. 형평성과 사회적 비용\n- 디지털 격차가 큰 저소득층이나 지역 간 불리함을 심화시키지 않는가? 정책 설계에서 형평성과 취약계층 보호를 어떻게 보장할 것인가?\n\n5. 실행성과 개인정보보호\n- 나이 인증·활동 제한의 기술적 구현이 개인정보보호와 보안에 어떤 위험을 가져오며, 비용과 행정 부담은 충분히 감당 가능한가?', '[진보] 1) 주장\n온라인 아동·청소년의 건강권과 학습권을 지키기 위해 셧다운 제도를 도입하는 것이 필요하다. 다만 제도 단독으로 효과를 보장하기 어렵다는 점을 인정하고, 가족 지원·교육 확충 등 보완책과 함께 설계해야 한다.\n\n2) 근거\n2014년 국내 연구는 셧다운제가 중독의 유발 원인과 강력한 1대1 상관관계를 증명하기 어렵고, 제도만으로 중독을 예방하기는 한계가 있음을 지적한다. 그러나 2017년 연세대 연구는 셧다운 제도가 인터넷 사용 습관과 수면 시간 등에 긍정적 영향을 미친다는 근거를 제시하며, 정책의 효과가 일부 존재함을 시사한다.\n\n3) 정책 제안\n- 법제화: 만 16세 이하에 대한 강제 셧다운을 기본으로 하고, 교육용 콘텐츠와 필수 커뮤니케이션 플랫폼 이용은 예외로 두되 엄격한 실시간 모니터링과 로그 남김을 의무화한다. 개인정보 최소수집 원칙을 적용하고, 연령 확인은 공공인증 시스템과 가명화된 데이터 처리로 보안 강화한다. \n- 가족·학교 지원: 가정에 대한 감독 지원금(가정 내 가족 상담·디지털 시민성 교육 비용), 학교마다 디지털 안전교실 정규과정 도입, 지역사회 상담 핫라인 운영으로 가족 부담을 분산한다.\n- 산업과 국제 협력: 국내 규제의 안정화를 위해 단계적 이행 로드맵을 마련하고, 국제 규제 차이에 따른 글로벌 플랫폼 협의체를 통해 기술표준과 개인정보 보호 기준의 국제적 조화를 추진한다.\n\n4) 실행 지표\n- 연 1회씩 독립기관에 의한 평가를 의무화하고, 3개 주요 지표로 효과를 측정한다: (a) 야간 접속 비율의 감소율(전년 대비 %), (b) 인터넷 중독 위험 척도 점수의 변화, (c) 학교 출석·학업성취도·수면시간의 개선지표. 목표치로는 3년간 야간 접속 20% 감소, 중독 위험 척도 15% 감소, 수면시간 30분 이상 증가를 설정한다.\n\n5) 결론\n셧다운 제도는 청소년의 건강과 교육환경을 보호하는 공익적 도구로서 필요하며, 보완정책과 근본적 사회지원과 함께 추진될 때 효과를 극대화할 수 있다. 이를 통해 디지털 격차를 줄이고 가정‧학교‧지역사회가 함께 책임지는 건강한 디지털 문화의 토대를 마련하자.'], 'turn': 1, 'last_speaker': 'prog'}}
# {'conservative': {'cons_history': ['1) 주장\n셧다운 제도는 폐지되어야 하며, 청소년 보호는 가족·학교의 자율적 관리와 시장 주체의 책임 있는 역할로 달성하는 것이 바람직하다.\n\n2) 근거\n2014년 국내 연구는 셧다운제가 중독의 직접적 예방에 한계가 있음을 지적했고, 2017년 연세대 연구는 제도 시행에 따라 습관이나 수면 등에 일부 긍정적 효과를 시사한다는 점을 제시한다. 다만 제도 자체의 효과가 불확실하고 우회 수단 증가, 개인정보보호 위험, 행정 부담 등의 부작용 가능성도 크므로 단일 제도에 의한 해결은 바람직하지 않다(근거: 해당 연구들).\n\n3) 정책 제안\n- 규제 최소화 원칙에 따라 가정·학교 중심의 디지털 시민성 교육과 지역사회 지원을 확대하고, 산업계는 자율규제와 성과기반 평가로 역량 강화(incentive 기반)하도록 한다.\n- 나이 인증은 개인정보 침해를 최소화하기 위해 공공인증 시스템과 가명데이터 처리로 설계하고, 데이터 최소수집 원칙을 엄격히 적용한다.\n- 예산은 가정 디지털 안전 지원 3년 간 연 200억원, 학교 디지털 안전교실·지역 상담 핫라인에 연간 각각 60억원씩 배정하는 등 총액 약 600억원 규모로 편성한다.\n- 실행은 1단계(가정·학교 중심의 프로그램 강화), 2단계(일부 예외 콘텐츠의 합리적 허용 및 모니터링 도입), 3단계(정책 효과 평가에 따른 조정)로 단계적으로 진행한다.\n\n4) 실행 지표\n- 독립 평가기관에 의한 연 1회 평가로 야간 이용 시간 감소율, 온라인 건강 위험척도 변화, 학업성취/수면시간 개선 지표를 3년 간 모니터링하며, 목표치는 야간 이용 15%, 건강 위험척도 10% 감소, 수면시간 20분 증가로 설정한다.\n\n5) 결론\n가정과 학교의 협력과 시장의 자율적 관리 체계를 강화해 청소년 건강권과 학습권을 확보하면서도, 과도한 행정개입과 개인정보·산업 침해를 최소화하는 방향이 가장 실효적이며 지속가능한 보호 체계이다.'], 'transcript': ['[사회자] 1. 효과성 및 부작용\n- 셧다운 제도가 아동·청소년의 게임 시간과 문제행동 감소에 실제로 효과가 있을까? 한편으로는 우회 수단 증가나 부작용이 나타날 가능성도 있다.\n\n2. 자유와 가족 책임의 균형\n- 청소년의 자유와 학습권을 보호하는 동시에 가족의 감독 권한과 사회적 책임의 균형은 어떻게 설정할 것인가? 제도 도입으로 가족 부담과 개입이 과도해지지 않는가?\n\n3. 산업 영향과 혁신\n- 제도 도입이 게임 산업의 혁신과 성장에 어떤 제약을 주며, 글로벌 플랫폼 간 규제 차이를 어떻게 조정할 것인가? 집행의 국제적 조화와 경쟁력 저하 우려는 없는가?\n\n4. 형평성과 사회적 비용\n- 디지털 격차가 큰 저소득층이나 지역 간 불리함을 심화시키지 않는가? 정책 설계에서 형평성과 취약계층 보호를 어떻게 보장할 것인가?\n\n5. 실행성과 개인정보보호\n- 나이 인증·활동 제한의 기술적 구현이 개인정보보호와 보안에 어떤 위험을 가져오며, 비용과 행정 부담은 충분히 감당 가능한가?', '[진보] 1) 주장\n온라인 아동·청소년의 건강권과 학습권을 지키기 위해 셧다운 제도를 도입하는 것이 필요하다. 다만 제도 단독으로 효과를 보장하기 어렵다는 점을 인정하고, 가족 지원·교육 확충 등 보완책과 함께 설계해야 한다.\n\n2) 근거\n2014년 국내 연구는 셧다운제가 중독의 유발 원인과 강력한 1대1 상관관계를 증명하기 어렵고, 제도만으로 중독을 예방하기는 한계가 있음을 지적한다. 그러나 2017년 연세대 연구는 셧다운 제도가 인터넷 사용 습관과 수면 시간 등에 긍정적 영향을 미친다는 근거를 제시하며, 정책의 효과가 일부 존재함을 시사한다.\n\n3) 정책 제안\n- 법제화: 만 16세 이하에 대한 강제 셧다운을 기본으로 하고, 교육용 콘텐츠와 필수 커뮤니케이션 플랫폼 이용은 예외로 두되 엄격한 실시간 모니터링과 로그 남김을 의무화한다. 개인정보 최소수집 원칙을 적용하고, 연령 확인은 공공인증 시스템과 가명화된 데이터 처리로 보안 강화한다. \n- 가족·학교 지원: 가정에 대한 감독 지원금(가정 내 가족 상담·디지털 시민성 교육 비용), 학교마다 디지털 안전교실 정규과정 도입, 지역사회 상담 핫라인 운영으로 가족 부담을 분산한다.\n- 산업과 국제 협력: 국내 규제의 안정화를 위해 단계적 이행 로드맵을 마련하고, 국제 규제 차이에 따른 글로벌 플랫폼 협의체를 통해 기술표준과 개인정보 보호 기준의 국제적 조화를 추진한다.\n\n4) 실행 지표\n- 연 1회씩 독립기관에 의한 평가를 의무화하고, 3개 주요 지표로 효과를 측정한다: (a) 야간 접속 비율의 감소율(전년 대비 %), (b) 인터넷 중독 위험 척도 점수의 변화, (c) 학교 출석·학업성취도·수면시간의 개선지표. 목표치로는 3년간 야간 접속 20% 감소, 중독 위험 척도 15% 감소, 수면시간 30분 이상 증가를 설정한다.\n\n5) 결론\n셧다운 제도는 청소년의 건강과 교육환경을 보호하는 공익적 도구로서 필요하며, 보완정책과 근본적 사회지원과 함께 추진될 때 효과를 극대화할 수 있다. 이를 통해 디지털 격차를 줄이고 가정‧학교‧지역사회가 함께 책임지는 건강한 디지털 문화의 토대를 마련하자.', '[보수] 1) 주장\n셧다운 제도는 폐지되어야 하며, 청소년 보호는 가족·학교의 자율적 관리와 시장 주체의 책임 있는 역할로 달성하는 것이 바람직하다.\n\n2) 근거\n2014년 국내 연구는 셧다운제가 중독의 직접적 예방에 한계가 있음을 지적했고, 2017년 연세대 연구는 제도 시행에 따라 습관이나 수면 등에 일부 긍정적 효과를 시사한다는 점을 제시한다. 다만 제도 자체의 효과가 불확실하고 우회 수단 증가, 개인정보보호 위험, 행정 부담 등의 부작용 가능성도 크므로 단일 제도에 의한 해결은 바람직하지 않다(근거: 해당 연구들).\n\n3) 정책 제안\n- 규제 최소화 원칙에 따라 가정·학교 중심의 디지털 시민성 교육과 지역사회 지원을 확대하고, 산업계는 자율규제와 성과기반 평가로 역량 강화(incentive 기반)하도록 한다.\n- 나이 인증은 개인정보 침해를 최소화하기 위해 공공인증 시스템과 가명데이터 처리로 설계하고, 데이터 최소수집 원칙을 엄격히 적용한다.\n- 예산은 가정 디지털 안전 지원 3년 간 연 200억원, 학교 디지털 안전교실·지역 상담 핫라인에 연간 각각 60억원씩 배정하는 등 총액 약 600억원 규모로 편성한다.\n- 실행은 1단계(가정·학교 중심의 프로그램 강화), 2단계(일부 예외 콘텐츠의 합리적 허용 및 모니터링 도입), 3단계(정책 효과 평가에 따른 조정)로 단계적으로 진행한다.\n\n4) 실행 지표\n- 독립 평가기관에 의한 연 1회 평가로 야간 이용 시간 감소율, 온라인 건강 위험척도 변화, 학업성취/수면시간 개선 지표를 3년 간 모니터링하며, 목표치는 야간 이용 15%, 건강 위험척도 10% 감소, 수면시간 20분 증가로 설정한다.\n\n5) 결론\n가정과 학교의 협력과 시장의 자율적 관리 체계를 강화해 청소년 건강권과 학습권을 확보하면서도, 과도한 행정개입과 개인정보·산업 침해를 최소화하는 방향이 가장 실효적이며 지속가능한 보호 체계이다.'], 'turn': 2, 'last_speaker': 'cons'}}
# {'progressive': {'prog_history': ['1) 주장\n온라인 아동·청소년의 건강권과 학습권을 지키기 위해 셧다운 제도를 도입하는 것이 필요하다. 다만 제도 단독으로 효과를 보장하기 어렵다는 점을 인정하고, 가족 지원·교육 확충 등 보완책과 함께 설계해야 한다.\n\n2) 근거\n2014년 국내 연구는 셧다운제가 중독의 유발 원인과 강력한 1대1 상관관계를 증명하기 어렵고, 제도만으로 중독을 예방하기는 한계가 있음을 지적한다. 그러나 2017년 연세대 연구는 셧다운 제도가 인터넷 사용 습관과 수면 시간 등에 긍정적 영향을 미친다는 근거를 제시하며, 정책의 효과가 일부 존재함을 시사한다.\n\n3) 정책 제안\n- 법제화: 만 16세 이하에 대한 강제 셧다운을 기본으로 하고, 교육용 콘텐츠와 필수 커뮤니케이션 플랫폼 이용은 예외로 두되 엄격한 실시간 모니터링과 로그 남김을 의무화한다. 개인정보 최소수집 원칙을 적용하고, 연령 확인은 공공인증 시스템과 가명화된 데이터 처리로 보안 강화한다. \n- 가족·학교 지원: 가정에 대한 감독 지원금(가정 내 가족 상담·디지털 시민성 교육 비용), 학교마다 디지털 안전교실 정규과정 도입, 지역사회 상담 핫라인 운영으로 가족 부담을 분산한다.\n- 산업과 국제 협력: 국내 규제의 안정화를 위해 단계적 이행 로드맵을 마련하고, 국제 규제 차이에 따른 글로벌 플랫폼 협의체를 통해 기술표준과 개인정보 보호 기준의 국제적 조화를 추진한다.\n\n4) 실행 지표\n- 연 1회씩 독립기관에 의한 평가를 의무화하고, 3개 주요 지표로 효과를 측정한다: (a) 야간 접속 비율의 감소율(전년 대비 %), (b) 인터넷 중독 위험 척도 점수의 변화, (c) 학교 출석·학업성취도·수면시간의 개선지표. 목표치로는 3년간 야간 접속 20% 감소, 중독 위험 척도 15% 감소, 수면시간 30분 이상 증가를 설정한다.\n\n5) 결론\n셧다운 제도는 청소년의 건강과 교육환경을 보호하는 공익적 도구로서 필요하며, 보완정책과 근본적 사회지원과 함께 추진될 때 효과를 극대화할 수 있다. 이를 통해 디지털 격차를 줄이고 가정‧학교‧지역사회가 함께 책임지는 건강한 디지털 문화의 토대를 마련하자.', '1) 주장\n청소년의 건강권과 학습권 보호를 위해 셧다운 제도를 도입하되, 가족·학교 중심의 지원과 개인정보 보호를 강화하는 종합 설계로 추진해야 한다.\n\n2) 근거\n2014년 국내 연구는 셧다운이 단독으로 중독 예방에 한계가 있음을 지적했고, 2017년 연세대 연구는 제도가 수면 시간 등 습관에 일부 긍정적 영향을 줄 수 있음을 시사한다. 다만 효과가 불완전하고 우회 수단·개인정보 위험 등의 부작용 가능성이 있어 제도만으로 해결하기 어렵다는 점도 함께 제시된다(근거: 연세대 연구/국내 연구 요지; 관련 국제문헌도 제도 설계와 개인정보 이슈를 함께 논의하고 있음). 따라서 효과를 극대화하려면 제도 자체를 보완하고 가정·학교·지역사회가 연계된 다층적 대응이 필요하다.\n\n3) 정책 제안\n- 법제화 및 기술설계: 만 16세 이하를 기본 대상으로 하고, 교육용 콘텐츠와 필수 플랫폼 이용은 예외로 두되 실시간 모니터링과 로그 기록을 의무화한다. 나이 인증은 공공 인증 체계와 가명화 데이터 처리로 최소수집 원칙을 적용한다.\n- 가정·학교 지원 강화: 가정 디지털 안전 지원금(가정상담·디지털 시민성 교육 비용)과 학교의 디지털 안전교실 정규과정 도입, 지역사회 상담 핫라인 구축으로 가족 부담을 분산한다.\n- 실행 로드맹 및 국제협력: 3단계 실행로드맵으로 점진 이행하고, 글로벌 플랫폼과의 협의체를 통해 기술표준과 개인정보 보호 기준의 국제적 조화를 추진한다.\n\n4) 실행 지표\n- 연 1회 독립기관 평가, 3개 핵심 지표 모니터링: (a) 야간 접속 비율의 감소(전년 대비 %), (b) 인터넷 중독 위험 척도 변화, (c) 수면시간·학업성취도 지표 개선(예: 수면시간 증가분) 및 형평성 지표(저소득층의 혜택 접근성) 포함. 목표 예시: 3년간 야간 접속 15–20% 감소, 중독 위험 척도 10–15% 감소, 수면시간 20–30분 증가.\n\n5) 결론\n셧다운 제도는 청소년의 건강권과 학습권을 보호하는 공익적 도구로서 필요하되, 독립평가와 3년 단위의 모니터링, 가정·학교·지역사회 간 협력, 개인정보 최소수집 및 가명처리 등 안전장치를 갖춘 경우에만 실효성과 사회적 수용성을 크게 높일 수 있다. 이러한 방향은 디지털 격차를 줄이고 사회 전체의 책임 있는 디지털 문화 형성에도 기여한다. (참고 근거: 연세대 연구 2017, 국내 연구들의 한계 지적 및 일부 긍정 신호)'], 'transcript': ['[사회자] 1. 효과성 및 부작용\n- 셧다운 제도가 아동·청소년의 게임 시간과 문제행동 감소에 실제로 효과가 있을까? 한편으로는 우회 수단 증가나 부작용이 나타날 가능성도 있다.\n\n2. 자유와 가족 책임의 균형\n- 청소년의 자유와 학습권을 보호하는 동시에 가족의 감독 권한과 사회적 책임의 균형은 어떻게 설정할 것인가? 제도 도입으로 가족 부담과 개입이 과도해지지 않는가?\n\n3. 산업 영향과 혁신\n- 제도 도입이 게임 산업의 혁신과 성장에 어떤 제약을 주며, 글로벌 플랫폼 간 규제 차이를 어떻게 조정할 것인가? 집행의 국제적 조화와 경쟁력 저하 우려는 없는가?\n\n4. 형평성과 사회적 비용\n- 디지털 격차가 큰 저소득층이나 지역 간 불리함을 심화시키지 않는가? 정책 설계에서 형평성과 취약계층 보호를 어떻게 보장할 것인가?\n\n5. 실행성과 개인정보보호\n- 나이 인증·활동 제한의 기술적 구현이 개인정보보호와 보안에 어떤 위험을 가져오며, 비용과 행정 부담은 충분히 감당 가능한가?', '[진보] 1) 주장\n온라인 아동·청소년의 건강권과 학습권을 지키기 위해 셧다운 제도를 도입하는 것이 필요하다. 다만 제도 단독으로 효과를 보장하기 어렵다는 점을 인정하고, 가족 지원·교육 확충 등 보완책과 함께 설계해야 한다.\n\n2) 근거\n2014년 국내 연구는 셧다운제가 중독의 유발 원인과 강력한 1대1 상관관계를 증명하기 어렵고, 제도만으로 중독을 예방하기는 한계가 있음을 지적한다. 그러나 2017년 연세대 연구는 셧다운 제도가 인터넷 사용 습관과 수면 시간 등에 긍정적 영향을 미친다는 근거를 제시하며, 정책의 효과가 일부 존재함을 시사한다.\n\n3) 정책 제안\n- 법제화: 만 16세 이하에 대한 강제 셧다운을 기본으로 하고, 교육용 콘텐츠와 필수 커뮤니케이션 플랫폼 이용은 예외로 두되 엄격한 실시간 모니터링과 로그 남김을 의무화한다. 개인정보 최소수집 원칙을 적용하고, 연령 확인은 공공인증 시스템과 가명화된 데이터 처리로 보안 강화한다. \n- 가족·학교 지원: 가정에 대한 감독 지원금(가정 내 가족 상담·디지털 시민성 교육 비용), 학교마다 디지털 안전교실 정규과정 도입, 지역사회 상담 핫라인 운영으로 가족 부담을 분산한다.\n- 산업과 국제 협력: 국내 규제의 안정화를 위해 단계적 이행 로드맵을 마련하고, 국제 규제 차이에 따른 글로벌 플랫폼 협의체를 통해 기술표준과 개인정보 보호 기준의 국제적 조화를 추진한다.\n\n4) 실행 지표\n- 연 1회씩 독립기관에 의한 평가를 의무화하고, 3개 주요 지표로 효과를 측정한다: (a) 야간 접속 비율의 감소율(전년 대비 %), (b) 인터넷 중독 위험 척도 점수의 변화, (c) 학교 출석·학업성취도·수면시간의 개선지표. 목표치로는 3년간 야간 접속 20% 감소, 중독 위험 척도 15% 감소, 수면시간 30분 이상 증가를 설정한다.\n\n5) 결론\n셧다운 제도는 청소년의 건강과 교육환경을 보호하는 공익적 도구로서 필요하며, 보완정책과 근본적 사회지원과 함께 추진될 때 효과를 극대화할 수 있다. 이를 통해 디지털 격차를 줄이고 가정‧학교‧지역사회가 함께 책임지는 건강한 디지털 문화의 토대를 마련하자.', '[보수] 1) 주장\n셧다운 제도는 폐지되어야 하며, 청소년 보호는 가족·학교의 자율적 관리와 시장 주체의 책임 있는 역할로 달성하는 것이 바람직하다.\n\n2) 근거\n2014년 국내 연구는 셧다운제가 중독의 직접적 예방에 한계가 있음을 지적했고, ...
# {'conservative': {'cons_history': ['1) 주장\n셧다운 제도는 폐지되어야 하며, 청소년 보호는 가족·학교의 자율적 관리와 시장 주체의 책임 있는 역할로 달성하는 것이 바람직하다.\n\n2) 근거\n2014년 국내 연구는 셧다운제가 중독의 직접적 예방에 한계가 있음을 지적했고, 2017년 연세대 연구는 제도 시행에 따라 습관이나 수면 등에 일부 긍정적 효과를 시사한다는 점을 제시한다. 다만 제도 자체의 효과가 불확실하고 우회 수단 증가, 개인정보보호 위험, 행정 부담 등의 부작용 가능성도 크므로 단일 제도에 의한 해결은 바람직하지 않다(근거: 해당 연구들).\n\n3) 정책 제안\n- 규제 최소화 원칙에 따라 가정·학교 중심의 디지털 시민성 교육과 지역사회 지원을 확대하고, 산업계는 자율규제와 성과기반 평가로 역량 강화(incentive 기반)하도록 한다.\n- 나이 인증은 개인정보 침해를 최소화하기 위해 공공인증 시스템과 가명데이터 처리로 설계하고, 데이터 최소수집 원칙을 엄격히 적용한다.\n- 예산은 가정 디지털 안전 지원 3년 간 연 200억원, 학교 디지털 안전교실·지역 상담 핫라인에 연간 각각 60억원씩 배정하는 등 총액 약 600억원 규모로 편성한다.\n- 실행은 1단계(가정·학교 중심의 프로그램 강화), 2단계(일부 예외 콘텐츠의 합리적 허용 및 모니터링 도입), 3단계(정책 효과 평가에 따른 조정)로 단계적으로 진행한다.\n\n4) 실행 지표\n- 독립 평가기관에 의한 연 1회 평가로 야간 이용 시간 감소율, 온라인 건강 위험척도 변화, 학업성취/수면시간 개선 지표를 3년 간 모니터링하며, 목표치는 야간 이용 15%, 건강 위험척도 10% 감소, 수면시간 20분 증가로 설정한다.\n\n5) 결론\n가정과 학교의 협력과 시장의 자율적 관리 체계를 강화해 청소년 건강권과 학습권을 확보하면서도, 과도한 행정개입과 개인정보·산업 침해를 최소화하는 방향이 가장 실효적이며 지속가능한 보호 체계이다.', '1) 주장\n셧다운 제도는 폐지되어야 하며, 청소년의 건강권·학습권 보호는 가족·학교의 자율적 관리와 플랫폼의 책임 있는 자율규제로 달성하는 것이 바람직하다.\n\n2) 근거\n연세대 연구(2017)와 다수 국내 연구는 제도가 수면 시간 등 습관에 일부 긍정적 영향을 주더라도 장기 효과가 불확실하고 우회 수단·개인정보 위험 등의 부작용이 크다고 지적한다(연세대 연구, 2017; 국내 연구 요지). 또한 차이-차이 분석 연구는 초기에는 인터넷 사용이 감소하나 시간이 지나며 효과가 사라지곤 하였고, 제도 자체의 지속적 개선 없이는 중독 감소나 건강 개선 효과가 지속되지 않는다는 점을 시사한다(PubMed 등 요약). 해외 연구 역시 제도 도입이 산업·사회에 미치는 부정적 영향과 ‘다양한 활동 대체’ 필요성을 강조한다. 따라서 제도 단독으로 문제를 해결하기보다는 자율 규제와 다층적 접근이 더 효과적이다(Telematics and Informatics 등).\n\n3) 정책 제안\n- 제도 철폐와 함께 가정·학교 중심의 디지털 시민성 교육과 지역사회 지원을 강화하고, 산업계는 자율규제와 성과기반 평가를 통해 책임감을 높이도록 한다. \n- 나이 인증 대신 플랫폼의 자율규제 도구를 강화하고, 데이터 최소수집 원칙과 개인정보 보호를 법제적 토대로 유지하되 공공기관의 과도한 개입은 최소화한다. \n- 예산은 최소한으로 설정하되 학교 디지털 안전교육(연간 60억원), 가정 디지털 안전지원(연간 40억원) 및 지역사회 상담 체계(연간 20억원) 등 총 120억원 규모를 3년간 추진하고, 민간과의 매칭펀드로 효율성을 높인다. \n- 3년간 3단계 로드맵으로 실행하고 국제협력을 통해 기술표준의 글로벌 조화를 모색한다.\n\n4) 실행 지표\n- 연 1회 독립평가를 통해 야간 접속 시간 변화, 건강 위험 인식 변화, 수면 시간·학업성취도 등 핵심 지표를 측정하고, 플랫폼의 자율규제 도구 활용률과 가족의 감독 질을 함께 점검한다. 목표 예시로는 수면시간 15분 증가, 학업성취도 소폭 상승, 자율규제 도구 사용 증가를 달성하는 방향으로 설정한다. 또한 저소득층 접근성 및 형평성 지표를 포함해 정책의 공정성을 확인한다.\n\n5) 결론\n가정·학교의 자율 관리와 플랫폼의 자율규제 강화는 과도한 행정개입을 줄이면서도 청소년 건강권과 학습권을 보호하는 더 지속가능한 방향이다. 독립평가를 통한 피드백과 국제 협력을 바탕으로 점진적으로 개선해 나가면 디지털 환경의 변화에 탄력적으로 대응할 수 있다.'], 'transcript': ['[사회자] 1. 효과성 및 부작용\n- 셧다운 제도가 아동·청소년의 게임 시간과 문제행동 감소에 실제로 효과가 있을까? 한편으로는 우회 수단 증가나 부작용이 나타날 가능성도 있다.\n\n2. 자유와 가족 책임의 균형\n- 청소년의 자유와 학습권을 보호하는 동시에 가족의 감독 권한과 사회적 책임의 균형은 어떻게 설정할 것인가? 제도 도입으로 가족 부담과 개입이 과도해지지 않는가?\n\n3. 산업 영향과 혁신\n- 제도 도입이 게임 산업의 혁신과 성장에 어떤 제약을 주며, 글로벌 플랫폼 간 규제 차이를 어떻게 조정할 것인가? 집행의 국제적 조화와 경쟁력 저하 우려는 없는가?\n\n4. 형평성과 사회적 비용\n- 디지털 격차가 큰 저소득층이나 지역 간 불리함을 심화시키지 않는가? 정책 설계에서 형평성과 취약계층 보호를 어떻게 보장할 것인가?\n\n5. 실행성과 개인정보보호\n- 나이 인증·활동 제한의 기술적 구현이 개인정보보호와 보안에 어떤 위험을 가져오며, 비용과 행정 부담은 충분히 감당 가능한가?', '[진보] 1) 주장\n온라인 아동·청소년의 건강권과 학습권을 지키기 위해 셧다운 제도를 도입하는 것이 필요하다. 다만 제도 단독으로 효과를 보장하기 어렵다는 점을 인정하고, 가족 지원·교육 확충 등 보완책과 함께 설계해야 한다.\n\n2) 근거\n2014년 국내 연구는 셧다운제가 중독의 유발 원인과 강력한 1대1 상관관계를 증명하기 어렵고, 제도만으로 중독을 예방하기는 한계가 있음을 지적한다. 그러나 2017년 연세대 연구는 셧다운 제도가 인터넷 사용 습관과 수면 시간 등에 긍정적 영향을 미친다는 근거를 제시하며, 정책의 효과가 일부 존재함을 시사한다.\n\n3) 정책 제안\n- 법제화: 만 16세 이하에 대한 강제 셧다운을 기본으로 하고, 교육용 콘텐츠와 필수 커뮤니케이션 플랫폼 이용은 예외로 두되 엄격한 실시간 모니터링과 로그 남김을 의무화한다. 개인정보 최소수집 원칙을 적용하고, 연령 확인은 공공인증 시스템과 가명화된 데이터 처리로 보안 강화한다. \n- 가족·학교 지원: 가정에 대한 감독 지원금(가정 내 가족 상담·디지털 시민성 교육 비용), 학교마다 디지털 안전교실 정규과정 도입, 지역사회 상담 핫라인 운영으로 가족 부담을 분산한다.\n- 산업과 국제 협력: 국내 규제의 안정화를 위해 단계적 이행 로드맵을 마련하고, 국제 규제 차이에 따른 글로벌 플랫폼 협의체를 통해 기술표준과 개인정보 보호 기준의 국제적 조화를 추진한다.\n\n4) 실행 지표\n- 연 1회씩 독립기관에 의한 평가를 의무화하고, 3개 주요 지표로 효과를 측정한다: (a) 야간 접속 비율의 감소율(전년 대비 %), (b) 인터넷 중독 위험 척도 점수의 변화, (c) 학교 출석·학업성취도·수면시간의 개선지표. 목표치로는 3년간 야간 접속 20% 감소, 중독 위험 척도 15% 감소, 수면시간 30분 이상 증가를 설정한다.\n\n5) 결론\n셧다운 제도는 청소년의 건강과 교육환경을 보호하는 공익적 도구로서 필요하며, 보완정책과 근본적 사회지원과 함께 추진될 때 효과를 극대화할 수 있다. 이를 통해 디지털 격차를 줄이고 가정‧학교‧지역사회가 함께 책임지는 건강한 디지털 문화의 토대를 마련하자.', '[보수] 1) 주장\n셧다운 제도는 폐지되어야 하며, 청소년 보호는 가족·학교의 자율적 관리와 시장 주체의 책임 있는 역할로 달성하는 것이 바람직하다.\n\n2) 근거\n2014년 국내 연구는 셧다운제가 중독의 직접적 예방에 한계가 있음을 지적했고, 2017년 연세대 연구는 제도 시행에 따라 습관이나 수면 등에 일부 긍정적 효과를 시사한다는 ...
# {'judge': {'final_report': '다음은 토론 기록을 토대로 도입 가능한 정책 설계안의 정리이다.\n\n1) 핵심 쟁점(주요 논점 3~5개)\n- 제도 효과성 vs 부작용: 셧다운 제도의 실제 효과가 불확실하고 우회 수단·부작용 가능성이 존재하는가?\n- 자유 vs 보호의 균형: 청소년의 자유와 학습권 보호와 가족·사회적 감독의 필요성 사이의 적정선은 어디인가?\n- 산업 영향과 국제 조화: 제도 도입이 게임 산업의 혁신/글로벌 플랫폼과의 경쟁력에 미치는 영향과 국제적 규제 차이 조정 문제.\n- 형평성 및 사회적 비용: 디지털 격차와 저소득층 등 취약계층에 대한 차별적 영향은 없는가?\n- 실행성과 개인정보보호: 나이 인증·로그 수집·모니터링의 비용·보안 리스크 및 전체 행정 부담은 감당 가능한가?\n\n2) 합의된 지점(공통적으로 인정되는 점 2~4개)\n- 제도 단독으로 효과를 보장하기 어렵고 보완 정책이 필요하다고 보는 점.\n- 개인정보 최소수집 원칙과 연령확인을 위한 보안 강화(공공인증 체계/가명처리 등)의 필요성.\n- 가정·학교 중심의 지원(가정 재정지원, 디지털 안전교실, 상담 핫라인 등)을 통한 부담 분산의 필요성.\n- 독립적 평가와 점진적 이행(다단계 로드맵, 3년 단위 평가)을 통한 정책 개선의 합의.\n\n3) 타협 가능한 정책 패키지(구체적 설계안; 단계·지표·예산원칙 포함)\n- 대상과 원칙\n  - 만 16세 이하를 기본 적용하되, 교육용 콘텐츠와 필수 플랫폼 이용은 예외로 둔다.\n- 기술설계 및 개인정보\n  - 실시간 모니터링 및 로그 기록 의무화, 연령인증은 공공인증 체계와 가명처리로 수행, 개인정보 최소수집 원칙 적용.\n- 가정·학교 지원\n  - 가정 디지털 안전 지원금, 학교 디지털 안전교실 정규과정 도입, 지역사회 상담 핫라인 구축으로 가족 부담 분산.\n- 실행 로드맹(3단계)\n  - 1단계: 가정·학교 중심의 프로그램 강화\n  - 2단계: 일부 예외 콘텐츠의 합리적 허용 및 모니터링 도입\n  - 3단계: 정책 효과 평가에 따른 조정 및 확대 여부 결정\n- 국제협력\n  - 국제 표준 및 개인정보 보호 기준의 조화를 위한 글로벌 플랫폼 협의체 구성 및 협력.\n- 평가 및 지표\n  - 연 1회 독립 평가, 핵심지표: (a) 야간 접속 감소율, (b) 인터넷 중독 위험 척도 변화, (c) 수면시간/학업성취도 개선, (d) 형평성 지표(저소득층 접근성) 포함.\n- 예산 원칙\n  - 비용-효과 원칙에 따라 편성; 필요 시 민간 매칭펀드 도입 가능.\n  - 총 예산 규모는 가정 부문 약 600억원(3년 간 연 200억원), 학교/지역 지원 부문 각 연 60억원 수준으로 시작하는 확장형 모델과, 필요 시 총 600~960억원 규모로 확대 가능한 형태를 병행 고려.\n\n4) 권고안 초안(조문 형태 요지, 6~10문장)\n1) 본 제도는 청소년의 건강권과 학습권 보호를 목표로 한다.\n2) 적용대상은 만 16세 이하의 온라인 이용 아동·청소년으로 하되, 교육용 콘텐츠와 필수 플랫폼 이용은 예외로 인정한다.\n3) 나이 인증은 공공 인증 체계와 가명화 처리로 수행하며, 실시간 모니터링과 로그 기록을 의무화한다.\n4) 개인정보 최소수집 원칙을 준수하고, 데이터 보안 및 접근 권한 관리 기준을 마련한다.\n5) 가정 디지털 안전 지원금, 학교 디지털 안전교실 도입, 지역사회 상담 핫라인을 통해 가족·학교 중심의 지원을 강화한다.\n6) 3단계 이행 로드맹과 국제 협력 체계를 마련하여 기술표준·개인정보 보호 기준의 국제적 조화를 추진한다.\n7) 연 1회의 독립 평가를 의무화하고, 야간 접속 감소율, 온라인 건강 위험 척도 변화, 수면시간 및 학업성취의 개선 등을 핵심 지표로 삼아 3년간 모니터링한다.\n8) 예산은 비용-효과 원칙을 바탕으로 책정하며, 가정·학교·지역 지원을 포함한 총 사업비를 600~960억원 규모로 편성하고 필요 시 민간 매칭펀드를 활용한다.\n9) 시행일은 공포 후 6개월 이내에 단계적 이행에 들어가며, 평가 결과에 따라 정책을 조정한다.\n10) 본 제도는 독립평가와 국제 협력을 통해 지속적으로 보완되며, 과도한 행정개입을 최소화하는 방향으로 운영한다.'}}
#
#
#
# 다음은 토론 기록을 토대로 도입 가능한 정책 설계안의 정리이다.
#
# 1) 핵심 쟁점(주요 논점 3~5개)
# - 제도 효과성 vs 부작용: 셧다운 제도의 실제 효과가 불확실하고 우회 수단·부작용 가능성이 존재하는가?
# - 자유 vs 보호의 균형: 청소년의 자유와 학습권 보호와 가족·사회적 감독의 필요성 사이의 적정선은 어디인가?
# - 산업 영향과 국제 조화: 제도 도입이 게임 산업의 혁신/글로벌 플랫폼과의 경쟁력에 미치는 영향과 국제적 규제 차이 조정 문제.
# - 형평성 및 사회적 비용: 디지털 격차와 저소득층 등 취약계층에 대한 차별적 영향은 없는가?
# - 실행성과 개인정보보호: 나이 인증·로그 수집·모니터링의 비용·보안 리스크 및 전체 행정 부담은 감당 가능한가?
#
# 2) 합의된 지점(공통적으로 인정되는 점 2~4개)
# - 제도 단독으로 효과를 보장하기 어렵고 보완 정책이 필요하다고 보는 점.
# - 개인정보 최소수집 원칙과 연령확인을 위한 보안 강화(공공인증 체계/가명처리 등)의 필요성.
# - 가정·학교 중심의 지원(가정 재정지원, 디지털 안전교실, 상담 핫라인 등)을 통한 부담 분산의 필요성.
# - 독립적 평가와 점진적 이행(다단계 로드맵, 3년 단위 평가)을 통한 정책 개선의 합의.
#
# 3) 타협 가능한 정책 패키지(구체적 설계안; 단계·지표·예산원칙 포함)
# - 대상과 원칙
#   - 만 16세 이하를 기본 적용하되, 교육용 콘텐츠와 필수 플랫폼 이용은 예외로 둔다.
# - 기술설계 및 개인정보
#   - 실시간 모니터링 및 로그 기록 의무화, 연령인증은 공공인증 체계와 가명처리로 수행, 개인정보 최소수집 원칙 적용.
# - 가정·학교 지원
#   - 가정 디지털 안전 지원금, 학교 디지털 안전교실 정규과정 도입, 지역사회 상담 핫라인 구축으로 가족 부담 분산.
# - 실행 로드맹(3단계)
#   - 1단계: 가정·학교 중심의 프로그램 강화
#   - 2단계: 일부 예외 콘텐츠의 합리적 허용 및 모니터링 도입
#   - 3단계: 정책 효과 평가에 따른 조정 및 확대 여부 결정
# - 국제협력
#   - 국제 표준 및 개인정보 보호 기준의 조화를 위한 글로벌 플랫폼 협의체 구성 및 협력.
# - 평가 및 지표
#   - 연 1회 독립 평가, 핵심지표: (a) 야간 접속 감소율, (b) 인터넷 중독 위험 척도 변화, (c) 수면시간/학업성취도 개선, (d) 형평성 지표(저소득층 접근성) 포함.
# - 예산 원칙
#   - 비용-효과 원칙에 따라 편성; 필요 시 민간 매칭펀드 도입 가능.
#   - 총 예산 규모는 가정 부문 약 600억원(3년 간 연 200억원), 학교/지역 지원 부문 각 연 60억원 수준으로 시작하는 확장형 모델과, 필요 시 총 600~960억원 규모로 확대 가능한 형태를 병행 고려.
#
# 4) 권고안 초안(조문 형태 요지, 6~10문장)
# 1) 본 제도는 청소년의 건강권과 학습권 보호를 목표로 한다.
# 2) 적용대상은 만 16세 이하의 온라인 이용 아동·청소년으로 하되, 교육용 콘텐츠와 필수 플랫폼 이용은 예외로 인정한다.
# 3) 나이 인증은 공공 인증 체계와 가명화 처리로 수행하며, 실시간 모니터링과 로그 기록을 의무화한다.
# 4) 개인정보 최소수집 원칙을 준수하고, 데이터 보안 및 접근 권한 관리 기준을 마련한다.
# 5) 가정 디지털 안전 지원금, 학교 디지털 안전교실 도입, 지역사회 상담 핫라인을 통해 가족·학교 중심의 지원을 강화한다.
# 6) 3단계 이행 로드맹과 국제 협력 체계를 마련하여 기술표준·개인정보 보호 기준의 국제적 조화를 추진한다.
# 7) 연 1회의 독립 평가를 의무화하고, 야간 접속 감소율, 온라인 건강 위험 척도 변화, 수면시간 및 학업성취의 개선 등을 핵심 지표로 삼아 3년간 모니터링한다.
# 8) 예산은 비용-효과 원칙을 바탕으로 책정하며, 가정·학교·지역 지원을 포함한 총 사업비를 600~960억원 규모로 편성하고 필요 시 민간 매칭펀드를 활용한다.
# 9) 시행일은 공포 후 6개월 이내에 단계적 이행에 들어가며, 평가 결과에 따라 정책을 조정한다.
# 10) 본 제도는 독립평가와 국제 협력을 통해 지속적으로 보완되며, 과도한 행정개입을 최소화하는 방향으로 운영한다.

# %%
topic = "고령화 시대 노년 연금 수령 나이 연장에 대한 찬반 논의"
out = graph.stream({"topic": topic, "max_turns": 4})
for stage in out:
    print(stage)

print("\n\n")
print(stage['judge']['final_report'])
# Out:
# {'moderator': {'moderator_questions': '1. [재정 지속 가능성과 개인 부담의 균형: 연령 연장은 연금 재정의 장기 지속 가능성을 높일 수 있지만, 조기 은퇴층의 소득 안정성은 약화될 수 있다.]\n2. [노동시장 영향과 생산성: 연령 연장이 노동시장 참여를 촉진하거나 유지할 수 있지만, 연령 차별과 건강 상태에 따라 고용 안정성과 생산성에 상반된 영향을 줄 수 있다.]\n3. [형평성과 공정성: 세대 간 부담 재분배의 공정성 문제와 직군별 차별 가능성으로 저임금·비정규직 등 취약계층이 불리해질 수 있다.]\n4. [정책 설계의 유연성: 점진적 도입, 건강상태 반영 예외, 부분 수령 옵션 등으로 공정성과 수용성을 높일 수 있다.]', 'transcript': ['[사회자] 1. [재정 지속 가능성과 개인 부담의 균형: 연령 연장은 연금 재정의 장기 지속 가능성을 높일 수 있지만, 조기 은퇴층의 소득 안정성은 약화될 수 있다.]\n2. [노동시장 영향과 생산성: 연령 연장이 노동시장 참여를 촉진하거나 유지할 수 있지만, 연령 차별과 건강 상태에 따라 고용 안정성과 생산성에 상반된 영향을 줄 수 있다.]\n3. [형평성과 공정성: 세대 간 부담 재분배의 공정성 문제와 직군별 차별 가능성으로 저임금·비정규직 등 취약계층이 불리해질 수 있다.]\n4. [정책 설계의 유연성: 점진적 도입, 건강상태 반영 예외, 부분 수령 옵션 등으로 공정성과 수용성을 높일 수 있다.]']}}
# {'conservative': {'cons_history': ['1) 주장\n고령화 시대에 연령 연장을 추진하되, 급격한 변화가 아니라 점진적 도입과 개인의 자율적 저축·보험 참여를 기반으로 해야 한다. 공적연금의 재정 안정성은 필요하지만, 조기 은퇴 인구의 소득 안정성도 민간 옵션의 자율성으로 보완하는 방안이 바람직하다.\n\n2) 근거\n노년층 인구의 급증은 공적부담을 가중시키며, 연금 재정의 장기 지속 가능성은 경제적 안정성의 필수 전제다. 또한 건강 상태와 직군에 따라 고용의 지속성이 달라질 수 있어, 연령 연장이 노동시장 효과를 일률적으로 판단하기 어렵다.\n\n3) 정책 제안\n단계적 도입으로 현행 65세에서 매 2년씩 연령을 상향하고, 건강상태 예외와 부분 수령 옵션을 도입해 수령 시점 선택의 자유를 확대한다. 민간 연금과 보험의 자율성을 높이고, 개인의 추가 저축에 대한 세제 혜택과 자동가입 같은 시장 기반 도구를 통해 책임의 주체를 국민으로 돌려준다.\n\n4) 실행 지표\n실행 지표로는 5년 주기로 재정 지속성 지표(연금 부채비율 및 재정 적자), 고용 참여율 변화, 부분 수령 이용률, 건강상태 예외 적용 비율 등을 측정한다.\n\n5) 결론\n이런 접근은 재정 안정성과 생산성, 공정성 사이에서 균형을 유지하며 자유시장 원칙과 개인 책임을 강화하는 합리적 선택이다.'], 'transcript': ['[사회자] 1. [재정 지속 가능성과 개인 부담의 균형: 연령 연장은 연금 재정의 장기 지속 가능성을 높일 수 있지만, 조기 은퇴층의 소득 안정성은 약화될 수 있다.]\n2. [노동시장 영향과 생산성: 연령 연장이 노동시장 참여를 촉진하거나 유지할 수 있지만, 연령 차별과 건강 상태에 따라 고용 안정성과 생산성에 상반된 영향을 줄 수 있다.]\n3. [형평성과 공정성: 세대 간 부담 재분배의 공정성 문제와 직군별 차별 가능성으로 저임금·비정규직 등 취약계층이 불리해질 수 있다.]\n4. [정책 설계의 유연성: 점진적 도입, 건강상태 반영 예외, 부분 수령 옵션 등으로 공정성과 수용성을 높일 수 있다.]', '[보수] 1) 주장\n고령화 시대에 연령 연장을 추진하되, 급격한 변화가 아니라 점진적 도입과 개인의 자율적 저축·보험 참여를 기반으로 해야 한다. 공적연금의 재정 안정성은 필요하지만, 조기 은퇴 인구의 소득 안정성도 민간 옵션의 자율성으로 보완하는 방안이 바람직하다.\n\n2) 근거\n노년층 인구의 급증은 공적부담을 가중시키며, 연금 재정의 장기 지속 가능성은 경제적 안정성의 필수 전제다. 또한 건강 상태와 직군에 따라 고용의 지속성이 달라질 수 있어, 연령 연장이 노동시장 효과를 일률적으로 판단하기 어렵다.\n\n3) 정책 제안\n단계적 도입으로 현행 65세에서 매 2년씩 연령을 상향하고, 건강상태 예외와 부분 수령 옵션을 도입해 수령 시점 선택의 자유를 확대한다. 민간 연금과 보험의 자율성을 높이고, 개인의 추가 저축에 대한 세제 혜택과 자동가입 같은 시장 기반 도구를 통해 책임의 주체를 국민으로 돌려준다.\n\n4) 실행 지표\n실행 지표로는 5년 주기로 재정 지속성 지표(연금 부채비율 및 재정 적자), 고용 참여율 변화, 부분 수령 이용률, 건강상태 예외 적용 비율 등을 측정한다.\n\n5) 결론\n이런 접근은 재정 안정성과 생산성, 공정성 사이에서 균형을 유지하며 자유시장 원칙과 개인 책임을 강화하는 합리적 선택이다.'], 'turn': 1, 'last_speaker': 'cons'}}
# {'progressive': {'prog_history': ['1) 주장\n- 고령화 시대의 연금정책은 공적연금의 재정 안정성과 모든 노년층의 기본 소득 보장을 함께 달성해야 한다. \n- 또한 건강 상태 예외 확대와 수령 시점의 유연성을 결합한 설계로 노동시장 재진입과 소득 다변화를 촉진해야 한다.\n\n2) 근거\n- 노인 빈곤과 노동시장 불평등은 사회적 비용을 증가시키므로 연금의 보장성 강화가 경제 활성화와 형평성 증진에 기여한다. \n- 건강 상태와 직무 특성에 따른 차별을 줄이면 고용 안정성과 생산성을 동시에 개선할 수 있다.\n\n3) 정책 제안\n- 최저 대체율을 60%로 보장하고, 소득 하위 40%에 추가 보정으로 75%까지 도달하도록 누진 구조를 도입한다. \n- 건강상태 예외의 범위를 중증질환, 육체노동의 직무 위험, 예방적 관리 등으로 확대해 실질적 노동 가능 기간을 반영한다. \n- 민간 연금의 보완성은 공적연금의 최소 보장을 벗어나지 않는 범위로 제한하고, 저소득층의 세제 혜택을 중심으로 설계한다.\n\n4) 실행 지표\n- 5년마다 재정 지속성, 빈곤율 변화, 고용 참여율 및 부분 수령 이용률을 평가한다.\n\n5) 결론\n- 이러한 조합은 재정 건전성과 형평성을 함께 달성하는 진보적이고 실현 가능한 해법이다.'], 'transcript': ['[사회자] 1. [재정 지속 가능성과 개인 부담의 균형: 연령 연장은 연금 재정의 장기 지속 가능성을 높일 수 있지만, 조기 은퇴층의 소득 안정성은 약화될 수 있다.]\n2. [노동시장 영향과 생산성: 연령 연장이 노동시장 참여를 촉진하거나 유지할 수 있지만, 연령 차별과 건강 상태에 따라 고용 안정성과 생산성에 상반된 영향을 줄 수 있다.]\n3. [형평성과 공정성: 세대 간 부담 재분배의 공정성 문제와 직군별 차별 가능성으로 저임금·비정규직 등 취약계층이 불리해질 수 있다.]\n4. [정책 설계의 유연성: 점진적 도입, 건강상태 반영 예외, 부분 수령 옵션 등으로 공정성과 수용성을 높일 수 있다.]', '[보수] 1) 주장\n고령화 시대에 연령 연장을 추진하되, 급격한 변화가 아니라 점진적 도입과 개인의 자율적 저축·보험 참여를 기반으로 해야 한다. 공적연금의 재정 안정성은 필요하지만, 조기 은퇴 인구의 소득 안정성도 민간 옵션의 자율성으로 보완하는 방안이 바람직하다.\n\n2) 근거\n노년층 인구의 급증은 공적부담을 가중시키며, 연금 재정의 장기 지속 가능성은 경제적 안정성의 필수 전제다. 또한 건강 상태와 직군에 따라 고용의 지속성이 달라질 수 있어, 연령 연장이 노동시장 효과를 일률적으로 판단하기 어렵다.\n\n3) 정책 제안\n단계적 도입으로 현행 65세에서 매 2년씩 연령을 상향하고, 건강상태 예외와 부분 수령 옵션을 도입해 수령 시점 선택의 자유를 확대한다. 민간 연금과 보험의 자율성을 높이고, 개인의 추가 저축에 대한 세제 혜택과 자동가입 같은 시장 기반 도구를 통해 책임의 주체를 국민으로 돌려준다.\n\n4) 실행 지표\n실행 지표로는 5년 주기로 재정 지속성 지표(연금 부채비율 및 재정 적자), 고용 참여율 변화, 부분 수령 이용률, 건강상태 예외 적용 비율 등을 측정한다.\n\n5) 결론\n이런 접근은 재정 안정성과 생산성, 공정성 사이에서 균형을 유지하며 자유시장 원칙과 개인 책임을 강화하는 합리적 선택이다.', '[진보] 1) 주장\n- 고령화 시대의 연금정책은 공적연금의 재정 안정성과 모든 노년층의 기본 소득 보장을 함께 달성해야 한다. \n- 또한 건강 상태 예외 확대와 수령 시점의 유연성을 결합한 설계로 노동시장 재진입과 소득 다변화를 촉진해야 한다.\n\n2) 근거\n- 노인 빈곤과 노동시장 불평등은 사회적 비용을 증가시키므로 연금의 보장성 강화가 경제 활성화와 형평성 증진에 기여한다. \n- 건강 상태와 직무 특성에 따른 차별을 줄이면 고용 안정성과 생산성을 동시에 개선할 수 있다.\n\n3) 정책 제안\n- 최저 대체율을 60%로 보장하고, 소득 하위 40%에 추가 보정으로 75%까지 도달하도록 누진 구조를 도입한다. \n- 건강상태 예외의 범위를 중증질환, 육체노동의 직무 위험, 예방적 관리 등으로 확대해 실질적 노동 가능 기간을 반영한다. \n- 민간 연금의 보완성은 공적연금의 최소 보장을 벗어나지 않는 범위로 제한하고, 저소득층의 세제 혜택을 중심으로 설계한다.\n\n4) 실행 지표\n- 5년마다 재정 지속성, 빈곤율 변화, 고용 참여율 및 부분 수령 이용률을 평가한다.\n\n5) 결론\n- 이러한 조합은 재정 건전성과 형평성을 함께 달성하는 진보적이고 실현 가능한 해법이다.'], 'turn': 2, 'last_speaker': 'prog'}}
# {'conservative': {'cons_history': ['1) 주장\n고령화 시대에 연령 연장을 추진하되, 급격한 변화가 아니라 점진적 도입과 개인의 자율적 저축·보험 참여를 기반으로 해야 한다. 공적연금의 재정 안정성은 필요하지만, 조기 은퇴 인구의 소득 안정성도 민간 옵션의 자율성으로 보완하는 방안이 바람직하다.\n\n2) 근거\n노년층 인구의 급증은 공적부담을 가중시키며, 연금 재정의 장기 지속 가능성은 경제적 안정성의 필수 전제다. 또한 건강 상태와 직군에 따라 고용의 지속성이 달라질 수 있어, 연령 연장이 노동시장 효과를 일률적으로 판단하기 어렵다.\n\n3) 정책 제안\n단계적 도입으로 현행 65세에서 매 2년씩 연령을 상향하고, 건강상태 예외와 부분 수령 옵션을 도입해 수령 시점 선택의 자유를 확대한다. 민간 연금과 보험의 자율성을 높이고, 개인의 추가 저축에 대한 세제 혜택과 자동가입 같은 시장 기반 도구를 통해 책임의 주체를 국민으로 돌려준다.\n\n4) 실행 지표\n실행 지표로는 5년 주기로 재정 지속성 지표(연금 부채비율 및 재정 적자), 고용 참여율 변화, 부분 수령 이용률, 건강상태 예외 적용 비율 등을 측정한다.\n\n5) 결론\n이런 접근은 재정 안정성과 생산성, 공정성 사이에서 균형을 유지하며 자유시장 원칙과 개인 책임을 강화하는 합리적 선택이다.', '1) 주장\n점진적이고 유연한 방식으로 연령 상향을 추진하고, 공적연금의 재정 건전성을 확보하는 한편 민간 저축과 보험의 자율성을 강화한다.\n\n2) 근거\n급격한 변화 대신 건강상태나 직무 특성에 따른 차이를 반영하면 노동시장 충격을 최소화하고 고용 안정성도 유지할 수 있다.\n\n3) 정책 제안\n연령 상향은 2년 간격으로 적용하고, 건강상태 예외의 범위를 중증질환, 육체노동의 직무 위험, 예방적 관리로 구체화한다.\n\n4) 정책 제안\n또한 부분 수령 옵션을 유지하고 자동가입 및 민간 저축에 대한 세제 혜택을 확대해 국민의 자율적 재정 준비를 촉진한다.\n\n5) 실행 지표\n5년 주기로 연금 재정지표를 점검하고(부채비율/재정적자), 고용 참여율과 부분 수령 이용률, 건강상태 예외 비율을 함께 모니터링한다.\n\n6) 결론\n이 같은 설계는 재정 지속성과 경제활동의 자유를 동시에 지키며, 정부 개입을 최소화하는 보수적 해법으로 실질적 적용 가능성이 높다.'], 'transcript': ['[사회자] 1. [재정 지속 가능성과 개인 부담의 균형: 연령 연장은 연금 재정의 장기 지속 가능성을 높일 수 있지만, 조기 은퇴층의 소득 안정성은 약화될 수 있다.]\n2. [노동시장 영향과 생산성: 연령 연장이 노동시장 참여를 촉진하거나 유지할 수 있지만, 연령 차별과 건강 상태에 따라 고용 안정성과 생산성에 상반된 영향을 줄 수 있다.]\n3. [형평성과 공정성: 세대 간 부담 재분배의 공정성 문제와 직군별 차별 가능성으로 저임금·비정규직 등 취약계층이 불리해질 수 있다.]\n4. [정책 설계의 유연성: 점진적 도입, 건강상태 반영 예외, 부분 수령 옵션 등으로 공정성과 수용성을 높일 수 있다.]', '[보수] 1) 주장\n고령화 시대에 연령 연장을 추진하되, 급격한 변화가 아니라 점진적 도입과 개인의 자율적 저축·보험 참여를 기반으로 해야 한다. 공적연금의 재정 안정성은 필요하지만, 조기 은퇴 인구의 소득 안정성도 민간 옵션의 자율성으로 보완하는 방안이 바람직하다.\n\n2) 근거\n노년층 인구의 급증은 공적부담을 가중시키며, 연금 재정의 장기 지속 가능성은 경제적 안정성의 필수 전제다. 또한 건강 상태와 직군에 따라 고용의 지속성이 달라질 수 있어, 연령 연장이 노동시장 효과를 일률적으로 판단하기 어렵다.\n\n3) 정책 제안\n단계적 도입으로 현행 65세에서 매 2년씩 연령을 상향하고, 건강상태 예외와 부분 수령 옵션을 도입해 수령 시점 선택의 자유를 확대한다. 민간 연금과 보험의 자율성을 높이고, 개인의 추가 저축에 대한 세제 혜택과 자동가입 같은 시장 기반 도구를 통해 책임의 주체를 국민으로 돌려준다.\n\n4) 실행 지표\n실행 지표로는 5년 주기로 재정 지속성 지표(연금 부채비율 및 재정 적자), 고용 참여율 변화, 부분 수령 이용률, 건강상태 예외 적용 비율 등을 측정한다.\n\n5) 결론\n이런 접근은 재정 안정성과 생산성, 공정성 사이에서 균형을 유지하며 자유시장 원칙과 개인 책임을 강화하는 합리적 선택이다.', '[진보] 1) 주장\n- 고령화 시대의 연금정책은 공적연금의 재정 안정성과 모든 노년층의 기본 소득 보장을 함께 달성해야 한다. \n- 또한 건강 상태 예외 확대와 수령 시점의 유연성을 결합한 설계로 노동시장 재진입과 소득 다변화를 촉진해야 한다.\n\n2) 근거\n- 노인 빈곤과 노동시장 불평등은 사회적 비용을 증가시키므로 연금의 보장성 강화가 경제 활성화와 형평성 증진에 기여한다. \n- 건강 상태와 직무 특성에 따른 차별을 줄이면 고용 안정성과 생산성을 동시에 개선할 수 있다.\n\n3) 정책 제안\n- 최저 대체율을 60%로 보장하고, 소득 하위 40%에 추가 보정으로 75%까지 도달하도록 누진 구조를 도입한다. \n- 건강상태 예외의 범위를 중증질환, 육체노동의 직무 위험, 예방적 관리 등으로 확대해 실질적 노동 가능 기간을 반영한다. \n- 민간 연금의 보완성은 공적연금의 최소 보장을 벗어나지 않는 범위로 제한하고, 저소득층의 세제 혜택을 중심으로 설계한다.\n\n4) 실행 지표\n- 5년마다 재정 지속성, 빈곤율 변화, 고용 참여율 및 부분 수령 이용률을 평가한다.\n\n5) 결론\n- 이러한 조합은 재정 건전성과 형평성을 함께 달성하는 진보적이고 실현 가능한 해법이다.', '[보수] 1) 주장\n점진적이고 유연한 방식으로 연령 상향을 추진하고, 공적연금의 재정 건전성을 확보하는 한편 민간 저축과 보험의 자율성을 강화한다.\n\n2) 근거\n급격한 변화 대신 건강상태나 직무 특성에 따른 차이를 반영하면 노동시장 충격을 최소화하고 고용 안정성도 유지할 수 있다.\n\n3) 정책 제안\n연령 상향은 2년 간격으로 적용하고, 건강상태 예외의 범위를 중증질환, 육체노동의 직무 위험, 예방적 관리로 구체화한다.\n\n4) 정책 제안\n또한 부분 수령 옵션을 유지하고 자동가입 및 민간 저축에 대한 세제 혜택을 확대해 국민의 자율적 재정 준비를 촉진한다.\n\n5) 실행 지표\n5년 주기로 연금 재정지표를 점검하고(부채비율/재정적자), 고용 참여율과 부분 수령 이용률, 건강상태 예외 비율을 함께 모니터링한다.\n\n6) 결론\n이 같은 설계는 재정 지속성과 경제활동의 자유를 동시에 지키며, 정부 개입을 최소화하는 보수적 해법으로 실질적 적용 가능성이 높다.'], 'turn': 3, 'last_speaker': 'cons'}}
# {'progressive': {'prog_history': ['1) 주장\n- 고령화 시대의 연금정책은 공적연금의 재정 안정성과 모든 노년층의 기본 소득 보장을 함께 달성해야 한다. \n- 또한 건강 상태 예외 확대와 수령 시점의 유연성을 결합한 설계로 노동시장 재진입과 소득 다변화를 촉진해야 한다.\n\n2) 근거\n- 노인 빈곤과 노동시장 불평등은 사회적 비용을 증가시키므로 연금의 보장성 강화가 경제 활성화와 형평성 증진에 기여한다. \n- 건강 상태와 직무 특성에 따른 차별을 줄이면 고용 안정성과 생산성을 동시에 개선할 수 있다.\n\n3) 정책 제안\n- 최저 대체율을 60%로 보장하고, 소득 하위 40%에 추가 보정으로 75%까지 도달하도록 누진 구조를 도입한다. \n- 건강상태 예외의 범위를 중증질환, 육체노동의 직무 위험, 예방적 관리 등으로 확대해 실질적 노동 가능 기간을 반영한다. \n- 민간 연금의 보완성은 공적연금의 최소 보장을 벗어나지 않는 범위로 제한하고, 저소득층의 세제 혜택을 중심으로 설계한다.\n\n4) 실행 지표\n- 5년마다 재정 지속성, 빈곤율 변화, 고용 참여율 및 부분 수령 이용률을 평가한다.\n\n5) 결론\n- 이러한 조합은 재정 건전성과 형평성을 함께 달성하는 진보적이고 실현 가능한 해법이다.', '1) 주장\n노년 연금 정책은 재정 지속성뿐 아니라 모든 노년층의 기본적 생활안정을 함께 달성해야 한다. 따라서 연령 상향은 2년 간격의 점진적 조정과 건강 상태 예외의 명확한 규정, 민간저축 자율성 확대를 병행하는 설계가 필요하다.\n\n2) 근거\n고령화로 인한 빈곤 위험과 노동시장 불평등이 사회적 비용을 증대시키므로 공적연금의 보장성 강화가 소비 안정성과 경제 활성화에 기여한다. 또한 건강 상태에 따른 차별 완화는 노동시장 내 고용 안정성과 생산성을 높일 수 있다.\n\n3) 정책 제안\n연령 상향은 65세를 시작점으로 2년 간격 재평가하고, 예외 상한을 법적으로 15%로 정하며 중증질환·육체노동의 직무 위험·예방 관리를 건강 예외의 구체적 범위로 확대한다. 부분 수령 옵션은 유지하되 자동가입의 소득 연동을 강화하고, 민간저축에 대해서는 연간 120만 원의 추가 소득공제와 10%의 세액공제 혜택으로 보완한다. 또한 정책의 재정 영향과 고용 효과를 매년 분석하고 2035년까지의 일몰조항과 5년 주기 재정·고용 모니터링 체계를 도입한다.\n\n4) 실행 지표\n5년 간격으로 재정지속성(부채비율, 재정적자), 고용참여율, 부분수령 이용률, 건강 예외 적용 비율, 빈곤율 변화, 민간저축 세제혜택 수용률을 함께 평가한다.\n\n5) 결론\n이 같은 설계는 재정 건전성과 노동시장 활성화를 동시에 달성하면서 형평성과 자율성을 모두 존중하는 진보적 해법으로 실질적 적용 가능성을 높인다.'], 'transcript': ['[사회자] 1. [재정 지속 가능성과 개인 부담의 균형: 연령 연장은 연금 재정의 장기 지속 가능성을 높일 수 있지만, 조기 은퇴층의 소득 안정성은 약화될 수 있다.]\n2. [노동시장 영향과 생산성: 연령 연장이 노동시장 참여를 촉진하거나 유지할 수 있지만, 연령 차별과 건강 상태에 따라 고용 안정성과 생산성에 상반된 영향을 줄 수 있다.]\n3. [형평성과 공정성: 세대 간 부담 재분배의 공정성 문제와 직군별 차별 가능성으로 저임금·비정규직 등 취약계층이 불리해질 수 있다.]\n4. [정책 설계의 유연성: 점진적 도입, 건강상태 반영 예외, 부분 수령 옵션 등으로 공정성과 수용성을 높일 수 있다.]', '[보수] 1) 주장\n고령화 시대에 연령 연장을 추진하되, 급격한 변화가 아니라 점진적 도입과 개인의 자율적 저축·보험 참여를 기반으로 해야 한다. 공적연금의 재정 안정성은 필요하지만, 조기 은퇴 인구의 소득 안정성도 민간 옵션의 자율성으로 보완하는 방안이 바람직하다.\n\n2) 근거\n노년층 인구의 급증은 공적부담을 가중시키며, 연금 재정의 장기 지속 가능성은 경제적 안정성의 필수 전제다. 또한 건강 상태와 직군에 따라 고용의 지속성이 달라질 수 있어, 연령 연장이 노동시장 효과를 일률적으로 판단하기 어렵다.\n\n3) 정책 제안\n단계적 도입으로 현행 65세에서 매 2년씩 연령을 상향하고, 건강상태 예외와 부분 수령 옵션을 도입해 수령 시점 선택의 자유를 확대한다. 민간 연금과 보험의 자율성을 높이고, 개인의 추가 저축에 대한 세제 혜택과 자동가입 같은 시장 기반 도구를 통해 책임의 주체를 국민으로 돌려준다.\n\n4) 실행 지표\n실행 지표로는 5년 주기로 재정 지속성 지표(연금 부채비율 및 재정 적자), 고용 참여율 변화, 부분 수령 이용률, 건강상태 예외 적용 비율 등을 측정한다.\n\n5) 결론\n이런 접근은 재정 안정성과 생산성, 공정성 사이에서 균형을 유지하며 자유시장 원칙과 개인 책임을 강화하는 합리적 선택이다.', '[진보] 1) 주장\n- 고령화 시대의 연금정책은 공적연금의 재정 안정성과 모든 노년층의 기본 소득 보장을 함께 달성해야 한다. \n- 또한 건강 상태 예외 확대와 수령 시점의 유연성을 결합한 설계로 노동시장 재진입과 소득 다변화를 촉진해야 한다.\n\n2) 근거\n- 노인 빈곤과 노동시장 불평등은 사회적 비용을 증가시키므로 연금의 보장성 강화가 경제 활성화와 형평성 증진에 기여한다. \n- 건강 상태와 직무 특성에 따른 차별을 줄이면 고용 안정성과 생산성을 동시에 개선할 수 있다.\n\n3) 정책 제안\n- 최저 대체율을 60%로 보장하고, 소득 하위 40%에 추가 보정으로 75%까지 도달하도록 누진 구조를 도입한다. \n- 건강상태 예외의 범위를 중증질환, 육체노동의 직무 위험, 예방적 관리 등으로 확대해 실질적 노동 가능 기간을 반영한다. \n- 민간 연금의 보완성은 공적연금의 최소 보장을 벗어나지 않는 범위로 제한하고, 저소득층의 세제 혜택을 중심으로 설계한다.\n\n4) 실행 지표\n- 5년마다 재정 지속성, 빈곤율 변화, 고용 참여율 및 부분 수령 이용률을 평가한다.\n\n5) 결론\n- 이러한 조합은 재정 건전성과 형평성을 함께 달성하는 진보적이고 실현 가능한 해법이다.', '[보수] 1) 주장\n점진적이고 유연한 방식으로 연령 상향을 추진하고, 공적연금의 재정 건전성을 확보하는 한편 민간 저축과 보험의 자율성을 강화한다.\n\n2) 근거\n급격한 변화 대신 건강상태나 직무 특성에 따른 차이를 반영하면 노동시장 충격을 최소화하고 고용 안정성도 유지할 수 있다.\n\n3) 정책 제안\n연령 상향은 2년 간격으로 적용하고, 건강상태 예외의 범위를 중증질환, 육체노동의 직무 위험, 예방적 관리로 구체화한다.\n\n4) 정책 제안\n또한 부분 수령 옵션을 유지하고 자동가입 및 민간 저축에 대한 세제 혜택을 확대해 국민의 자율적 재정 준비를 촉진한다.\n\n5) 실행 지표\n5년 주기로 연금 재정지표를 점검하고(부채비율/재정적자), 고용 참여율과 부분 수령 이용률, 건강상태 예외 비율을 함께 모니터링한다.\n\n6) 결론\n이 같은 설계는 재정 지속성과 경제활동의 자유를 동시에 지키며, 정부 개입을 최소화하는 보수적 해법으로 실질적 적용 가능성이 높다.', '[진보] 1) 주장\n노년 연금 정책은 재정 지속성뿐 아니라 모든 노년층의 기본적 생활안정을 함께 달성해야 한다. 따라서 연령 상향은 2년 간격의 점진적 조정과 건강 상태 예외의 명확한 규정, 민간저축 자율성 확대를 병행하는 설계가 필요하다.\n\n2) 근거\n고령화로 인한 빈곤 위험과 노동시장 불평등이 사회적 비용을 증대시키므로 공적연금의 보장성 강화가 소비 안정성과 경제 활성화에 기여한다. 또한 건강 상태에 따른 차별 완화는 노동시장 내 고용 안정성과 생산성을 높일 수 있다.\n\n3) 정책 제안\n연령 상향은 65세를 시작점으로 2년 간격 재평가하고, 예외 상한을 법적으로 15%로 정하며 중증질환·육체노동의 직무 위험·예방 관리를 건강 예외의 구체적 범위로 확대한다. 부분 수령 옵션은 유지하되 자동가입의 소득 연동을 강화하고, 민간저축에 대해서는 연간 120만 원의 추가 소득공제와 10%의 세액공제 혜택으로 보완한다. 또한 정책의 재정 영향과 고용 효과를 매년 분석하고 2035년까지 ...
# {'judge': {'final_report': '다음은 주어진 토론 기록을 바탕으로 도입 가능한 구체 제도 설계안을 간결하게 정리한 내용입니다.\n\n1) 핵심 쟁점 3~5개\n- 공적연금의 재정 지속 가능성과 세대 간 부담 재분배의 공정성 문제: 고령화에 따른 재정 압박과 젊은 세대의 부담 증가 여부, 취약계층의 부담 경감 필요성.\n- 노동시장에 미치는 영향과 생산성: 연령 연장이 고용 참여율과 생산성에 미치는 긍정적 효과와 연령 차별 및 건강상태에 따른 실효성 차이.\n- 형평성 강화 vs 자유시장 기반 설계의 균형: 저임금‧비정규직 등 취약계층 보호 필요성과 민간저축/보험의 자율성 강화 사이의 균형.\n- 정책 설계의 유연성: 점진적 도입, 건강상태 예외의 구체화, 부분 수령 옵션 등 수용성·공정성 확보를 위한 조치의 필요성.\n- 민간저축·시장 도구의 역할 한계와 보완: 공적연금의 최소 보장을 유지하되 민간저축의 보완 기능을 어떻게 설계할지의 문제.\n\n2) 합의된 지점 2~4개\n- 점진적 도입의 필요성: 급격한 변화보다 2년 간격의 단계적 연령 상향 방식이 합리적이라는 점.\n- 건강상태 예외 및 부분 수령의 필요성: 예외 범위(특정 질환, 직무 위험, 예방 관리)와 수령 시점의 부분적 선택권에 대한 합의 가능성.\n- 민간저축 자율성 강화 및 세제 혜택 도입: 민간저축·보험의 자율성 확대를 통해 개인 책임성 강화 필요성에 공감대 존재.\n- 재정 건전성·고용 효과 모니터링의 필요성: 5년 주기의 재정 및 고용 관련 지표 모니터링 체계 구축에 대한 합의.\n- 공적연금의 최소 보장 유지에 대한 공감대: 보장성 강화와 최소 대체율 유지 등 최소 보장의 원칙 유지 필요성에 대한 합의 가능성.\n\n3) 타협 가능한 정책 패키지(단계·지표·예산원칙 포함)\n- 단계적 추진 방향\n  - 시작점: 65세를 기초로 삼고, 2년 간격으로 연령 상향을 적용.\n  - 건강상태 예외: 예외 범위를 중증질환, 육체노동의 직무 위험, 예방적 관리까지로 확대하되 예외 상한을 15%로 설정.\n  - 수령 옵션: 부분 수령 옵션은 유지하되 수령 시점의 선택과 자유를 확대.\n  - 민간저축·세제: 자동가입 제도 도입 및 민간저축에 대한 연간 120만원 추가 소득공제와 10% 세액공제 혜택 부여.\n  - 최저 대체율·누진보정: 공적연금의 최소 대체율은 60%를 보장하고, 소득하위 40%에는 추가 보정으로 75%까지 도달하도록 누진 구조 적용.\n  - 재정·고용 모니터링: 5년 주기로 재정 지속성(부채비율·재정적자)과 고용참여율, 부분 수령 이용률, 건강 예외 적용 비율, 빈곤율 변화, 민간저축 세제혜택 수용률 등을 평가.\n  - 예산원칙: 재정건전성 우선 원칙 아래, 2035년 일몰조항 도입 및 5년 단위 재평가 체계 구축. 민간저축 자율성 강화는 공적연금의 최소 보장을 훼손하지 않는 범위에서 운용.\n\n4) 권고안 초안(조문 형태 요지; 6~10문장)\n- 제1조 목적: 본 법은 공적연금의 재정 지속가능성과 형평성 및 노동시장 활성화를 동시에 달성하기 위한 제도적 기반을 마련하는 것을 목적으로 한다.\n- 제2조 연령조정: 65세를 시작점으로 하여 2년 간격으로 연령을 상향하되, 2035년까지 점진적으로 조정한다.\n- 제3조 건강상태 예외: 예외 범위는 중증질환, 육체노동의 직무 위험, 예방적 관리를 포함하며, 예외 적용 비율의 상한은 15%로 한다.\n- 제4조 부분 수령: 부분 수령 옵션은 계속 유지하고, 수령 시점의 선택권을 확대한다.\n- 제5조 민간저축·세제 지원: 자동가입 제도를 도입하고, 민간저축에 대해 연간 120만원 추가 소득공제 및 10%의 세액공제를 부여한다.\n- 제6조 최소 보장 및 누진구조: 공적연금의 최소 대체율을 60%로 보장하고, 소득 하위 40%에 한해 추가 보정으로 75%까지 도달하도록 누진 구조를 적용한다.\n- 제7조 재정·고용 모니터링: 5년마다 재정 지속성(부채비율·재정적자), 고용참여율, 부분 수령 이용률, 건강 예외 적용 비율, 빈곤율 변화 등 지표를 평가하고, 필요 시 정책 조정을 위한 권고를 제공한다.\n- 제8조 기간적 일몰 및 재평가: 2035년까지 일몰조항을 두고, 매 5년 간 재평가 체계를 운용한다.\n- 시행일: 본 법은 공포 후 시행되며, 구체적 시행일은 시행령으로 정한다.\n\n참고로, 위 초안은 토론에서 제시된 방향성(점진적 도입, 건강예외, 부분수령, 민간저축의 자율성 확대, 최소 보장 유지, 5년 모니터링)을 반영해 구체적 조문 형태로 간략 요지화한 것입니다.'}}
#
#
#
# 다음은 주어진 토론 기록을 바탕으로 도입 가능한 구체 제도 설계안을 간결하게 정리한 내용입니다.
#
# 1) 핵심 쟁점 3~5개
# - 공적연금의 재정 지속 가능성과 세대 간 부담 재분배의 공정성 문제: 고령화에 따른 재정 압박과 젊은 세대의 부담 증가 여부, 취약계층의 부담 경감 필요성.
# - 노동시장에 미치는 영향과 생산성: 연령 연장이 고용 참여율과 생산성에 미치는 긍정적 효과와 연령 차별 및 건강상태에 따른 실효성 차이.
# - 형평성 강화 vs 자유시장 기반 설계의 균형: 저임금‧비정규직 등 취약계층 보호 필요성과 민간저축/보험의 자율성 강화 사이의 균형.
# - 정책 설계의 유연성: 점진적 도입, 건강상태 예외의 구체화, 부분 수령 옵션 등 수용성·공정성 확보를 위한 조치의 필요성.
# - 민간저축·시장 도구의 역할 한계와 보완: 공적연금의 최소 보장을 유지하되 민간저축의 보완 기능을 어떻게 설계할지의 문제.
#
# 2) 합의된 지점 2~4개
# - 점진적 도입의 필요성: 급격한 변화보다 2년 간격의 단계적 연령 상향 방식이 합리적이라는 점.
# - 건강상태 예외 및 부분 수령의 필요성: 예외 범위(특정 질환, 직무 위험, 예방 관리)와 수령 시점의 부분적 선택권에 대한 합의 가능성.
# - 민간저축 자율성 강화 및 세제 혜택 도입: 민간저축·보험의 자율성 확대를 통해 개인 책임성 강화 필요성에 공감대 존재.
# - 재정 건전성·고용 효과 모니터링의 필요성: 5년 주기의 재정 및 고용 관련 지표 모니터링 체계 구축에 대한 합의.
# - 공적연금의 최소 보장 유지에 대한 공감대: 보장성 강화와 최소 대체율 유지 등 최소 보장의 원칙 유지 필요성에 대한 합의 가능성.
#
# 3) 타협 가능한 정책 패키지(단계·지표·예산원칙 포함)
# - 단계적 추진 방향
#   - 시작점: 65세를 기초로 삼고, 2년 간격으로 연령 상향을 적용.
#   - 건강상태 예외: 예외 범위를 중증질환, 육체노동의 직무 위험, 예방적 관리까지로 확대하되 예외 상한을 15%로 설정.
#   - 수령 옵션: 부분 수령 옵션은 유지하되 수령 시점의 선택과 자유를 확대.
#   - 민간저축·세제: 자동가입 제도 도입 및 민간저축에 대한 연간 120만원 추가 소득공제와 10% 세액공제 혜택 부여.
#   - 최저 대체율·누진보정: 공적연금의 최소 대체율은 60%를 보장하고, 소득하위 40%에는 추가 보정으로 75%까지 도달하도록 누진 구조 적용.
#   - 재정·고용 모니터링: 5년 주기로 재정 지속성(부채비율·재정적자)과 고용참여율, 부분 수령 이용률, 건강 예외 적용 비율, 빈곤율 변화, 민간저축 세제혜택 수용률 등을 평가.
#   - 예산원칙: 재정건전성 우선 원칙 아래, 2035년 일몰조항 도입 및 5년 단위 재평가 체계 구축. 민간저축 자율성 강화는 공적연금의 최소 보장을 훼손하지 않는 범위에서 운용.
#
# 4) 권고안 초안(조문 형태 요지; 6~10문장)
# - 제1조 목적: 본 법은 공적연금의 재정 지속가능성과 형평성 및 노동시장 활성화를 동시에 달성하기 위한 제도적 기반을 마련하는 것을 목적으로 한다.
# - 제2조 연령조정: 65세를 시작점으로 하여 2년 간격으로 연령을 상향하되, 2035년까지 점진적으로 조정한다.
# - 제3조 건강상태 예외: 예외 범위는 중증질환, 육체노동의 직무 위험, 예방적 관리를 포함하며, 예외 적용 비율의 상한은 15%로 한다.
# - 제4조 부분 수령: 부분 수령 옵션은 계속 유지하고, 수령 시점의 선택권을 확대한다.
# - 제5조 민간저축·세제 지원: 자동가입 제도를 도입하고, 민간저축에 대해 연간 120만원 추가 소득공제 및 10%의 세액공제를 부여한다.
# - 제6조 최소 보장 및 누진구조: 공적연금의 최소 대체율을 60%로 보장하고, 소득 하위 40%에 한해 추가 보정으로 75%까지 도달하도록 누진 구조를 적용한다.
# - 제7조 재정·고용 모니터링: 5년마다 재정 지속성(부채비율·재정적자), 고용참여율, 부분 수령 이용률, 건강 예외 적용 비율, 빈곤율 변화 등 지표를 평가하고, 필요 시 정책 조정을 위한 권고를 제공한다.
# - 제8조 기간적 일몰 및 재평가: 2035년까지 일몰조항을 두고, 매 5년 간 재평가 체계를 운용한다.
# - 시행일: 본 법은 공포 후 시행되며, 구체적 시행일은 시행령으로 정한다.
#
# 참고로, 위 초안은 토론에서 제시된 방향성(점진적 도입, 건강예외, 부분수령, 민간저축의 자율성 확대, 최소 보장 유지, 5년 모니터링)을 반영해 구체적 조문 형태로 간략 요지화한 것입니다.
